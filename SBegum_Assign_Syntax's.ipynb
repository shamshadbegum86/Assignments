# %%
# ----> Assign(4b) ----> Variable's_Create

1. List[] ----> Use this Brackets[] & To Accept Duplicates 

Syntax:-
    
    lst=["value1","value2","value3","value4"]
    lst
    
Ex:- lst_Fnames=["Shahina","Rehana","Aliya","Hanima"]
     lst_Fnames   
    
2. Tuple()----> Use this Brackets() & To Accept Duplicates

Syntax:-
    
    Tuple=("value1","value2","value3","value4") 
    Tuple
    
Ex:- Tuple_Fmembers=("Md.Ali","Balkis Jaha","Shahnaz Begum","Irfan")
     Tuple_Fmembers
    
    
3. Set{}  ----> Use this Brackets{} & To Remove Duplicates 

# ----> To Accept Alphabetical Order (First Capital next Small letters)

Syntax:-
    
    Set={"value1","value2","value3","value4"}   
    Set
    
Ex:- Colour_names={"Pink","Yellow","Red","Blue"}
     Colour_names

# %%
# ----> Assign(5a) ----> Dictinary={key:key_values}

Syntax:-
    
        dict={"key":["Key_value1","Key_value2","Key_value3"]}
        dict         

# ----> Dictionary to Create 'Data Frame'

Syntax:-
    
        df=pd.DataFrame(dict)
        df

# %%
# ----> Assign(5b) ----> Conditions

conditions:
3

if             ---->  Only One Condition 'True'
if  else       ----> 'True (or) False'  &  Yes (or) No
if  elif  else ---->  More than two values (Multiple) 'True (or) False'

1. Syntax:-
    
        if condition:
            statement
    
2. Syntax:-
     
        if condition: 
            statement
        else:
            statement

3. Syntax:-
    
        if condition:
            statement
        elif condition:
             statement
        elif condition:
             statement   
        elif condition:
             statement
        else: 
            statement
    
Logical Operators: (and  or  not)

# %%
# ----> Assign(6) ----> For_loop ----> list[], Tuple(), Set{}

  
Syntax's:-

for A in list:
    print(A)
    
for B in tuple:
    print(B) 
    
for S in set:
    print(S) 
    
for SB in range(0,91,9):
    
    print(SB)

# %%
# ----> Assign(8a) ----> Pandas ----> (.txt_file)

Ex:-
       
import pandas
import pandas as pd
Friend_names=pd.read_csv(r"C:\Users\hp\Begum_Excel_Sheets\Friend_names.txt")
Friend_names

# ----> Assign(8b) ----> Pandas ----> (.excel_file)

Ex:-
    
Friend_names=pd.read_excel(r"C:\Users\hp\Begum_Excel_Sheets\Friends_names.xlsx")
Friend_names

# %%
# ----> Assign(9) ----> 'Basic_Checks'

Basic Checks:-
    
[1. df.index   --> To Display --> Starting_index & Ending_index & Step(ex:1)
 2. df.shape   --> To Display --> Total_Rows & Total_Columns
 3. df.head()  --> To Display --> Starting Five_Rows & Columns
 4. df.tail()  --> To Display --> Ending Five_Rows & Columns
 5. df.columns --> To Display --> Columns (index) Heddings
 6. df.info()  --> To Display --> Total Data information
 7. df.dtypes  --> To Display --> dtype: object
 8. type(df)]  --> To Display --> pandas.core.frame.DataFrame

# %%
# ----> Assign(10) ----> Python_Filters


1). Only ['Intelligent'] ----> Use Symbol(==) 

Syntax:-
    
    a) df1=df[df["Key"]=="Key_Value"]
       df1
              (or) 
        
    b) df[df["Key"]=="Key_Value"]
    
Ex:-
    
    a) df1=df_Fnames[df_Fnames["Quality"]=="Intelligent"]
       df1
                   (or) 
        
    b) df_Fnames[df_Fnames["Quality"]=="Intelligent"] 
    
    
2). Only "Brothers and Sisters" ----> More key_values use list[] ---> isin(list)

Syntax:-
    
    lst=['value1','value2']
    
    
    a) df1=df[df.Key.isin(lst)]
       df1
             (or)
        
    b) df[df.Key.isin(lst)]

Ex:-
    lst_BS=['Brother','Sister']
    
    
    a) df1=df_Fmembers[df_Fmembers.Relation.isin(lst_BS)]
       df1
                 (or)  
    
    b) df_Fmembers[df_Fmembers.Relation.isin(lst_BS)]
     
    
3). # ----> Not_Parent ----> Only 'One Key_Value' -----> Use Symbol (!)

Syntax:-
    
    a) df1=df[df["key"]!="Key_value"]
       df1
                (or)
        
    b) df[df["key"]!="Key_value"] 
    
Ex:- 
    a) Not_Parent=df_Fmembers[df_Fmembers["Relation"]!="Parent"]
       Not_Parent
                     (or)
        
    b) df_Fmembers[df_Fmembers["Relation"]!="Parent"]
    
4). # ----> 'Not_Soup (and) Not_Fry ----> Two 'Key_Values' ----> Use Symbol(~)

Syntax:-
    
    lst=['value1','value2']

    a) df1=df[~df.Key.isin(lst)]
       df1
            (or)
        
    b) df[~df.Key.isin(lst)]
    
Ex:-
    
    lst_SF=["Soup","Fry"]
    
    a) Not_SF=df_Veg[~df_Veg.Taste.isin(lst_SF)]
       Not_SF 
   
              (or)

    b) df_Veg[~df_Veg.Taste.isin(lst_SF)]
    
    
5). # ----> 'Either' Brothers 'Or' Parents ----> Use Symbol (|)  

Syntax:-
    
    a) df1=df[(df["Key"]=="Key_value")|(df["Key"]=="Key_value")]
       df1
    
                       (or)
        
    b) df[(df["Key"]=="Key_value")|(df["Key"]=="Key_value")]
    
Ex:-
    
    a) Or_Condition=df_Fmembers[(df_Fmembers["Relation"]=="Brother")|(df_Fmembers["Relation"]=="Parent")]
       Or_Condition
    
                        (or)
          
    b) df_Fmembers[(df_Fmembers["Relation"]=="Brother")|(df_Fmembers["Relation"]=="Parent")]

# %%
# ----> Assign(11) ----> Python_Append 

a) Table_1

import pandas
import pandas as pd
df_Bf=pd.read_excel(r"C:\Users\hp\Downloads\Boysfriends_Names.xlsx")
df_Bf

b) Table_2

import pandas as pd
df_Gf=pd.read_excel(r"C:\Users\hp\Downloads\Girlsfriends_Names.xlsx")
df_Gf


# -----> Append -----> (Join 'Two_Tables')

axis=0 ----> To Display Tables ---->  "One by One"

axis=1 ----> To Display Tables ---->  "Side by Side"

Syntax:-

    a) Ap=pd.concat([df1,df2],axis=0)
       Ap
        
    b) Ap1=pd.concat([df1,df2],axis=1)
       Ap1
        
    
Ex:-
    
    a) Ap=pd.concat([df_b,df_g],axis=0)
       Ap
    
    b) Ap1=pd.concat([df_b,df_g],axis=1)
       Ap1 
        
        
# -----> Append -----> (Join 'Three_Tables')

Syntax:-
    
    a) Ap=pd.concat([df1,df2,df3],axis=0)
       Ap
        
    b) Ap1=pd.concat([df1,df2,df3],axis=1)
       Ap1
    
Ex:-
    
axis=0 

    Ap_Seasons=pd.concat([df_Winter,df_Summer,df_Rainy],axis=0)
    Ap_Seasons
    
axis=1 

    Ap_Seasons1=pd.concat([df_Winter,df_Summer,df_Rainy],axis=1)
    Ap_Seasons1
    
    
# -----> Append -----> (Join 'Four_Tables')


Syntax:-
    
    a) Ap=pd.concat([df1,df2,df3,df4],axis=0)
       Ap
        
    b) Ap1=pd.concat([df1,df2,df3,df4],axis=1)
       Ap1
    
Ex:-
    
axis=0 
     
    Ap_FColour=pd.concat([df_Red,df_White,df_Pink,df_Yellow],axis=0)
    Ap_FColour
    
    
axis=1 
    
    Ap_FColour=pd.concat([df_Red,df_White,df_Pink,df_Yellow],axis=0)
    Ap_FColour

# %%
# ----> Assignment_(12)_Merges

# ----> [Inner_Join, Left_Join, Right Join, Outer_Join, Cross_Join]


Syntax:-
    
 # Inner join 

    df_inner=pd.merge(df1,df2, how='inner',on='key')
    df_inner
                   (or)
        
    df_inner=df1.merge(df2, how='inner',on='key')
    df_inner
    
EX:-
    
# 1.Inner join

df_inner=pd.merge(df1_sch, df2_col, how='inner', on='Friend_Names')
df_inner
                    (OR) 
    
df_inner_merge=df1_sch.merge(df2_col, how='inner',on='Friend_Names')
df_inner_merge

# 2.Left join

df_left=pd.merge(df1_sch, df2_col, how='left', on='Friend_Names')
df_left

# 3.Right join

df_right=pd.merge(df1_sch, df2_col, how='right', on='Friend_Names')
df_right

# 4.Outer join

df_outer=pd.merge(df1_sch, df2_col, how='outer', on='Friend_Names')
df_outer

cross=pd.merge(df1_sch, df2_col, how='cross')
cross

# %%
# ----> Assignment_(13)_Groupby

1) # ---> To Create 'School_mets' Table

Ex:-
    
import pandas
import pandas as pd
Schoolmets=pd.read_excel(r"C:\Users\hp\Downloads\Schoolmets_Names.xlsx")
Schoolmets
  
2) # ---> To Create 'College_mets' Table

Ex:-
    
Collegemets=pd.read_excel(r"C:\Users\hp\Downloads\Collegemets_Names.xlsx")
Collegemets

# ------> Unique()

Syntax:-
    
    df.key.unique()
    
Ex:-
    
    Schoolmets.Quality.unique()
    

# ------> Count()

Syntax:-
    
    df.key.count()
    
Ex:-
   
    Schoolmets.Quality.count()
    
# ------> Groupby

Syntax:-
    
    a) df.groupby("key").count()  ---> Groupby 'One Column'
    
    b) df.groupby(["key1","key2"]).count() ---> Groupby 'Two Columns'
    
Ex:-
    
    a) Schoolmets.groupby("Quality").count()
    
    b) Schoolmets.groupby(["Quality","Friend Names"]).count()
