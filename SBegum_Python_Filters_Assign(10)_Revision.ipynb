# %%
# ----> Assignment(10) ----> Python_Filters_Practice

# %%
# Task: Write a program

# Q> create and import below files

# 1. Create a friend_names.xls file  (atleast 10 names, columns are FriendName,Quality)
# Q1> create a dataframe which contains only your intelligent friends list.
# Q2> create a dataframe which contains only your funny friends list.


# 2. Create a family_members.xls file  (atleast 10 names, columns are FamilyMemberName*Relation)
# Q1> create a dataframe which contains only your brothers and sisters list.
# Q2> create a dataframe which contains only your parents list.
# Q3> create a dataframe which not contains your parents list.
# Q4> create a dataframe which not contains your brothers list.
# Q5> create a dataframe which contains either your brothers list or parents list.
# Q5> create a dataframe which contains your brothers list and parents list.


# 3. Create a Vegfood_items.xlsx file  (atleast 10 names, columns are VegFoodName*Taste)
# Q1>create a dataframe which are  soups items
# Q2>create a dataframe which are curry items
# Q3>create a dataframe which are fry items
# Q4>create a dataframe which contains soups and fry items
# Q5>create a dataframe which not contains soups and fry items
# Q6>create a dataframe which contains either soup or fry items



# 4. Create a NonVegfood_items.xlsx file  (atleast 10 names, columns are NonVegFoodName*Taste)
# Q1>create a dataframe which contains only chicken items
# Q2>create a dataframe which contains only mutton items
# Q3>create a dataframe which contains only Fry items
# Q4>create a dataframe which contains only Fry and chicken items
# Q5>create a dataframe which not contains Fry and chicken items
# Q6>create a dataframe which contains either Fry or mutton items

# 5. Create a month_names.xlsx file (atleast 12 names, columns are MonthName*Season)
# Q1>create a dataframe which contains only winter season months
# Q2>create a dataframe which contains only summer season months
# Q3>create a dataframe which contains only rainy season months
# Q4>create a dataframe which contains only winter and summer season months
# Q5>create a dataframe which not contains summer and rainy season months
# Q6>create a dataframe which contains either winter or rainy items


# 6. Create a flower_names.xlsx file  (atleast 12 names, columns are FlowercolourName_in_English^FlowercolourName_in_Hindi^FlowercolourName_in_Telugu)
# Q1>create a dataframe which contains only red colour flower list
# Q2>create a dataframe which contains only white colour flower list
# Q3>create a dataframe which contains only pink colour flower list
# Q4>create a dataframe which contains only red and pink colour list
# Q5>create a dataframe which not contains red and white colour list
# Q6>create a dataframe which contains either red or pink colour list

# %%
# Q> create and import below files

# 1. Create a friend_names.xls file  (atleast 10 names, columns are FriendName,Quality)
# Q1> create a dataframe which contains only your intelligent friends list.
# Q2> create a dataframe which contains only your funny friends list.

# %%
# 1. Create a friend_names.xls file  (atleast 10 names, columns are FriendName,Quality)

# %%
import pandas
import pandas as pd
df_fnames=pd.read_excel(r"C:\Users\hp\Downloads\friend_names.xlsx")
df_fnames
# Out:
#    S.No. Friend_Names      Quality
# 0      1        Salma       Active
# 1      2       Hamida  Intelligent
# 2      3      Jameela         Good
# 3      4      Shafika        Funny
# 4      5      Sultana         Best
# 5      6       Hanima  Intelligent
# 6      7        Munny     Innocent
# 7      8       Rehana        Funny
# 8      9         Asma  Intelligent
# 9     10       Vahida       Clever

# %%
# ----> Only ['Intelligent'] ----> Use Symbol(==) 

Syntax:-
    
    a)  df1=df[df["Key"]=="Key_Value"]
        df1
    
                (or) 
        
    b)  df[df["Key"]=="Key_Value"]

# %%
# Q1> create a dataframe which contains only your intelligent friends list.

df1=df_fnames[df_fnames["Quality"]=="Intelligent"]
df1
# Out:
#    S.No. Friend_Names      Quality
# 1      2       Hamida  Intelligent
# 5      6       Hanima  Intelligent
# 8      9         Asma  Intelligent

# %%
(or)

# %%
df_fnames[df_fnames["Quality"]=="Intelligent"]
# Out:
#    S.No. Friend_Names      Quality
# 1      2       Hamida  Intelligent
# 5      6       Hanima  Intelligent
# 8      9         Asma  Intelligent

# %%
# Q2> create a dataframe which contains only your funny friends list.

# %%
# ----> Only  ["Funny"]

# %%
df_fnames[df_fnames["Quality"]=="Funny"]
# Out:
#    S.No. Friend_Names Quality
# 3      4      Shafika   Funny
# 7      8       Rehana   Funny

# %%
# 2. Create a family_members.xls file  (atleast 10 names, columns are FamilyMemberName*Relation)
# Q1> create a dataframe which contains only your brothers and sisters list.
# Q2> create a dataframe which contains only your parents list.
# Q3> create a dataframe which not contains your parents list.
# Q4> create a dataframe which not contains your brothers list.
# Q5> create a dataframe which contains either your brothers list or parents list.
# Q6> create a dataframe which contains your brothers list and parents list.

# %%
# 2. Create a family_members.xls file  (atleast 10 names, columns are FamilyMemberName*Relation)

# %%
df_fmembers=pd.read_excel(r"C:\Users\hp\Downloads\family_names.xlsx")
df_fmembers
# Out:
#    S.No.   Family_members        Relation
# 0      1          Md. Ali          Parent
# 1      2      Balkis Jaha          Parent
# 2      3         Shahanaz          Sister
# 3      4       Afzal Shaw         Brother
# 4      5         Shakeela          Sister
# 5      6     Abdul Haffiz  Brother_in_law
# 6      7           Irfhan         Brother
# 7      8  Md. Karamatulla         Husbend
# 8      9           Shannu        Daughter
# 9     10             Banu        Daughter

# %%
# ----> Only "Brothers and Sisters" ----> More key_values use list[] ---> isin(list)

Syntax:-

    lst=['value1','value2']
    
    a) df1=df[df.Key.isin(lst)]
       df1
            (or)
            
    b) df[df.Key.isin(lst)]

# %%
# Q1> create a dataframe which contains only your brothers and sisters list.

# %%
lst=['Brother','Sister']

df1=df_fmembers[df_fmembers.Relation.isin(lst)]
df1
# Out:
#    S.No. Family_members Relation
# 2      3       Shahanaz   Sister
# 3      4     Afzal Shaw  Brother
# 4      5       Shakeela   Sister
# 6      7         Irfhan  Brother

# %%
(or)

# %%
lst=['Brother','Sister']

df_fmembers[df_fmembers.Relation.isin(lst)]
# Out:
#    S.No. Family_members Relation
# 2      3       Shahanaz   Sister
# 3      4     Afzal Shaw  Brother
# 4      5       Shakeela   Sister
# 6      7         Irfhan  Brother

# %%
# ------> Only ['Parent']

# %%
# Q2> create a dataframe which contains only your parents list.

# %%
df1=df_fmembers[df_fmembers["Relation"]=="Parent"]
df1
# Out:
#    S.No. Family_members Relation
# 0      1        Md. Ali   Parent
# 1      2    Balkis Jaha   Parent

# %%
(or)

# %%
df_fmembers[df_fmembers["Relation"]=="Parent"]
# Out:
#    S.No. Family_members Relation
# 0      1        Md. Ali   Parent
# 1      2    Balkis Jaha   Parent

# %%
# ----> Not_Parent ----> Only 'One Key_value' -----> Use Symbol (!)

Syntax:-
    
    a) df1=df[df["key"]!="Key_value"]
       df1
    
              (or)
        
    b) df[df["key"]!="Key_value"]

# %%
# Q3> create a dataframe which not contains your parents list.

# %%
Not_Parent=df_fmembers[df_fmembers["Relation"]!="Parent"]
Not_Parent
# Out:
#    S.No.   Family_members        Relation
# 2      3         Shahanaz          Sister
# 3      4       Afzal Shaw         Brother
# 4      5         Shakeela          Sister
# 5      6     Abdul Haffiz  Brother_in_law
# 6      7           Irfhan         Brother
# 7      8  Md. Karamatulla         Husbend
# 8      9           Shannu        Daughter
# 9     10             Banu        Daughter

# %%
(or)

# %%
df_fmembers[df_fmembers["Relation"]!="Parent"]
# Out:
#    S.No.   Family_members        Relation
# 2      3         Shahanaz          Sister
# 3      4       Afzal Shaw         Brother
# 4      5         Shakeela          Sister
# 5      6     Abdul Haffiz  Brother_in_law
# 6      7           Irfhan         Brother
# 7      8  Md. Karamatulla         Husbend
# 8      9           Shannu        Daughter
# 9     10             Banu        Daughter

# %%
# Q4> create a dataframe which not contains your brothers list.

# %%
# --------> Not_Brothers

# %%
df_fmembers[df_fmembers["Relation"]!="Brother"]
# Out:
#    S.No.   Family_members        Relation
# 0      1          Md. Ali          Parent
# 1      2      Balkis Jaha          Parent
# 2      3         Shahanaz          Sister
# 4      5         Shakeela          Sister
# 5      6     Abdul Haffiz  Brother_in_law
# 7      8  Md. Karamatulla         Husbend
# 8      9           Shannu        Daughter
# 9     10             Banu        Daughter

# %%
(or)

# %%
Not_Brothers=df_fmembers[df_fmembers["Relation"]!="Brother"]
Not_Brothers
# Out:
#    S.No.   Family_members        Relation
# 0      1          Md. Ali          Parent
# 1      2      Balkis Jaha          Parent
# 2      3         Shahanaz          Sister
# 4      5         Shakeela          Sister
# 5      6     Abdul Haffiz  Brother_in_law
# 7      8  Md. Karamatulla         Husbend
# 8      9           Shannu        Daughter
# 9     10             Banu        Daughter

# %%
# Q5> create a dataframe which contains either your brothers list or parents list.

# %%
# ----> 'Either' Brothers 'Or' Parents ----> Use Symbol (|)  

Syntax:-
    
    a) df1=df[(df["Key"]=="Key_value")|(df["Key"]=="Key_value")]
       df1
    
                       (or)
        
    b) df[(df["Key"]=="Key_value")|(df["Key"]=="Key_value")]

# %%
Or_Condition=df_fmembers[(df_fmembers["Relation"]=="Brother")|(df_fmembers["Relation"]=="Parent")]
Or_Condition
# Out:
#    S.No. Family_members Relation
# 0      1        Md. Ali   Parent
# 1      2    Balkis Jaha   Parent
# 3      4     Afzal Shaw  Brother
# 6      7         Irfhan  Brother

# %%
(or)

# %%
df_fmembers[(df_fmembers["Relation"]=="Brother")|(df_fmembers["Relation"]=="Parent")]
# Out:
#    S.No. Family_members Relation
# 0      1        Md. Ali   Parent
# 1      2    Balkis Jaha   Parent
# 3      4     Afzal Shaw  Brother
# 6      7         Irfhan  Brother

# %%
# Q6> create a dataframe which contains your brothers list and parents list.

# %%
# ----> Brothers 'and' Parents ----> Two 'Key_values'   Use isin(lst)

# %%
lst=['Brother','Parent']

df_BP=df_fmembers[df_fmembers.Relation.isin(lst)]
df_BP
# Out:
#    S.No. Family_members Relation
# 0      1        Md. Ali   Parent
# 1      2    Balkis Jaha   Parent
# 3      4     Afzal Shaw  Brother
# 6      7         Irfhan  Brother

# %%
(or)

# %%
lst=['Brother','Parent']

df_fmembers[df_fmembers.Relation.isin(lst)]
# Out:
#    S.No. Family_members Relation
# 0      1        Md. Ali   Parent
# 1      2    Balkis Jaha   Parent
# 3      4     Afzal Shaw  Brother
# 6      7         Irfhan  Brother

# %%
# 3. Create a Vegfood_items.xlsx file  (atleast 10 names, columns are VegFoodName*Taste)
# Q1>create a dataframe which are  soups items
# Q2>create a dataframe which are curry items
# Q3>create a dataframe which are fry items
# Q4>create a dataframe which contains soups and fry items
# Q5>create a dataframe which not contains soups and fry items
# Q6>create a dataframe which contains either soup or fry items

# %%
# 3. Create a Vegfood_items.xlsx file  (atleast 10 names, columns are VegFoodName*Taste)

# %%
df_Veg=pd.read_excel(r"C:\Users\hp\Downloads\Vegfood_items.xlsx")
df_Veg
# Out:
#     S.No. Veg Food Names  Taste
# 0       1     Tomato Dal  Curry
# 1       2           Aalu    Fry
# 2       3         Tomato   Soup
# 3       4        Cabbage    Fry
# 4       5  Pudina Chatny  Spicy
# 5       6        Brinjal  Curry
# 6       7  Lady's Finger    Fry
# 7       8         Banana  Curry
# 8       9   GingerChatny  Spicy
# 9      10        Pongali  Sweet
# 10     11         Noodle   Soup
# 11     12     Sweet Corn   Soup

# %%
# Q1>create a dataframe which are  soups items

# %%
# ------> Only ['Soup']

# %%
df_S=df_Veg[df_Veg["Taste"]=="Soup"]
df_S
# Out:
#     S.No. Veg Food Names Taste
# 2       3         Tomato  Soup
# 10     11         Noodle  Soup
# 11     12     Sweet Corn  Soup

# %%
(or)

# %%
df_Veg[df_Veg["Taste"]=="Soup"]
# Out:
#     S.No. Veg Food Names Taste
# 2       3         Tomato  Soup
# 10     11         Noodle  Soup
# 11     12     Sweet Corn  Soup

# %%
# Q2>create a dataframe which are curry items

# %%
# ------> Only ['Curry']

# %%
df_C=df_Veg[df_Veg["Taste"]=="Curry"]
df_C
# Out:
#    S.No. Veg Food Names  Taste
# 0      1     Tomato Dal  Curry
# 5      6        Brinjal  Curry
# 7      8         Banana  Curry

# %%
(or)

# %%
df_Veg[df_Veg["Taste"]=="Curry"]
# Out:
#    S.No. Veg Food Names  Taste
# 0      1     Tomato Dal  Curry
# 5      6        Brinjal  Curry
# 7      8         Banana  Curry

# %%
# Q3>create a dataframe which are fry items

# %%
# ------> Only ['Fry']

# %%
df_F=df_Veg[df_Veg["Taste"]=="Fry"]
df_F
# Out:
#    S.No. Veg Food Names Taste
# 1      2           Aalu   Fry
# 3      4        Cabbage   Fry
# 6      7  Lady's Finger   Fry

# %%
(or)

# %%
df_Veg[df_Veg["Taste"]=="Fry"]
# Out:
#    S.No. Veg Food Names Taste
# 1      2           Aalu   Fry
# 3      4        Cabbage   Fry
# 6      7  Lady's Finger   Fry

# %%
# Q4>create a dataframe which contains soups and fry items

# %%
# ----> Soup and Fry

# %%
lst1=['Soup','Fry']

df_SF=df_Veg[df_Veg.Taste.isin(lst1)]
df_SF
# Out:
#     S.No. Veg Food Names Taste
# 1       2           Aalu   Fry
# 2       3         Tomato  Soup
# 3       4        Cabbage   Fry
# 6       7  Lady's Finger   Fry
# 10     11         Noodle  Soup
# 11     12     Sweet Corn  Soup

# %%
(or)

# %%
df_Veg[df_Veg.Taste.isin(lst1)]
# Out:
#     S.No. Veg Food Names Taste
# 1       2           Aalu   Fry
# 2       3         Tomato  Soup
# 3       4        Cabbage   Fry
# 6       7  Lady's Finger   Fry
# 10     11         Noodle  Soup
# 11     12     Sweet Corn  Soup

# %%
# Q5>create a dataframe which not contains soups and fry items

# %%
# ----> 'Not_Soup and Fry ----> Two 'Key_values' ----> Use Symbol(~)

Syntax:-

    lst=['value1','value2']

    a) df1=df[~df.Key.isin(lst)]
       df1
             (or)
        
    b) df[~df.Key.isin(lst)]

# %%
lst2=["Soup","Fry"]

Not_SF=df_Veg[~df_Veg.Taste.isin(lst2)]
Not_SF
# Out:
#    S.No. Veg Food Names  Taste
# 0      1     Tomato Dal  Curry
# 4      5  Pudina Chatny  Spicy
# 5      6        Brinjal  Curry
# 7      8         Banana  Curry
# 8      9   GingerChatny  Spicy
# 9     10        Pongali  Sweet

# %%
(or)

# %%
lst2=["Soup","Fry"]

df_Veg[~df_Veg.Taste.isin(lst2)]
# Out:
#    S.No. Veg Food Names  Taste
# 0      1     Tomato Dal  Curry
# 4      5  Pudina Chatny  Spicy
# 5      6        Brinjal  Curry
# 7      8         Banana  Curry
# 8      9   GingerChatny  Spicy
# 9     10        Pongali  Sweet

# %%
# Q6>create a dataframe which contains either soup or fry items

# %%
# -----> 'Either' Soup 'Or' Fry items

# %%
df_SF=df_Veg[(df_Veg["Taste"]=="Soup")|(df_Veg["Taste"]=="Fry")]
df_SF
# Out:
#     S.No. Veg Food Names Taste
# 1       2           Aalu   Fry
# 2       3         Tomato  Soup
# 3       4        Cabbage   Fry
# 6       7  Lady's Finger   Fry
# 10     11         Noodle  Soup
# 11     12     Sweet Corn  Soup

# %%
(or)

# %%
df_Veg[(df_Veg["Taste"]=="Soup")|(df_Veg["Taste"]=="Fry")]
# Out:
#     S.No. Veg Food Names Taste
# 1       2           Aalu   Fry
# 2       3         Tomato  Soup
# 3       4        Cabbage   Fry
# 6       7  Lady's Finger   Fry
# 10     11         Noodle  Soup
# 11     12     Sweet Corn  Soup

# %%
# 4. Create a NonVegfood_items.xlsx file  (atleast 10 names, columns are NonVegFoodName*Taste)
# Q1>create a dataframe which contains only chicken items
# Q2>create a dataframe which contains only mutton items
# Q3>create a dataframe which contains only Fry items
# Q4>create a dataframe which contains only Fry and chicken items
# Q5>create a dataframe which not contains Fry and chicken items
# Q6>create a dataframe which c#ontains either Fry or mutton items

# %%
# 4. Create a NonVegfood_items.xlsx file  (atleast 10 names, columns are NonVegFoodName*Taste)

# %%
df_NVeg=pd.read_excel(r"C:\Users\hp\Downloads\NVegfood_items.xlsx")
df_NVeg
# Out:
#     S.No. Non Veg  Food Names    Taste
# 0       1      Matton Biryani   Matton
# 1       2       Chicken Curry  Chicken
# 2       3        Matton Curry   Matton
# 3       4                Fish      Fry
# 4       5       Matton Khurma   Matton
# 5       6          Matton Fry      Fry
# 6       7   Chicken lolly Pop  Chicken
# 7       8              Kheema   Matton
# 8       9     Chicken Biryani  Chicken
# 9      10         Chicken Fry      Fry
# 10     11      Chilly Chicken  Chicken
# 11     12              Prawns      Fry

# %%
# Q1>create a dataframe which contains only chicken items

# %%
# ------> Only ['Chicken']

# %%
df_NVeg[df_NVeg["Taste"]=="Chicken"]
# Out:
#     S.No. Non Veg  Food Names    Taste
# 1       2       Chicken Curry  Chicken
# 6       7   Chicken lolly Pop  Chicken
# 8       9     Chicken Biryani  Chicken
# 10     11      Chilly Chicken  Chicken

# %%
# Q2>create a dataframe which contains only mutton items

# %%
# ------> Only ['Matton']

# %%
df_NVeg[df_NVeg["Taste"]=="Matton"]
# Out:
#    S.No. Non Veg  Food Names   Taste
# 0      1      Matton Biryani  Matton
# 2      3        Matton Curry  Matton
# 4      5       Matton Khurma  Matton
# 7      8              Kheema  Matton

# %%
# Q3>create a dataframe which contains only Fry items

# %%
# ------> Only ['Fry']

# %%
df_NVeg[df_NVeg["Taste"]=="Fry"]
# Out:
#     S.No. Non Veg  Food Names Taste
# 3       4                Fish   Fry
# 5       6          Matton Fry   Fry
# 9      10         Chicken Fry   Fry
# 11     12              Prawns   Fry

# %%
# Q4>create a dataframe which contains only Fry and chicken items

# %%
# ----> Only Fry and Chicken

# %%
lst3=["Fry","Chicken"]

df_NVeg[df_NVeg.Taste.isin(lst3)]
# Out:
#     S.No. Non Veg  Food Names    Taste
# 1       2       Chicken Curry  Chicken
# 3       4                Fish      Fry
# 5       6          Matton Fry      Fry
# 6       7   Chicken lolly Pop  Chicken
# 8       9     Chicken Biryani  Chicken
# 9      10         Chicken Fry      Fry
# 10     11      Chilly Chicken  Chicken
# 11     12              Prawns      Fry

# %%
# Q5>create a dataframe which not contains Fry and chicken items

# %%
# ----> 'Not' Fry and Chicken

# %%
lst3=["Fry","Chicken"]

df_NVeg[~df_NVeg.Taste.isin(lst3)]
# Out:
#    S.No. Non Veg  Food Names   Taste
# 0      1      Matton Biryani  Matton
# 2      3        Matton Curry  Matton
# 4      5       Matton Khurma  Matton
# 7      8              Kheema  Matton

# %%
# Q6>create a dataframe which contains either Fry or mutton items

# %%
# ----> 'Either' Fry 'or' Mutton items

# %%
df_NVeg[(df_NVeg["Taste"]=="Fry") | (df_NVeg["Taste"]=="Matton")]
# Out:
#     S.No. Non Veg  Food Names   Taste
# 0       1      Matton Biryani  Matton
# 2       3        Matton Curry  Matton
# 3       4                Fish     Fry
# 4       5       Matton Khurma  Matton
# 5       6          Matton Fry     Fry
# 7       8              Kheema  Matton
# 9      10         Chicken Fry     Fry
# 11     12              Prawns     Fry

# %%
# 5. Create a month_names.xlsx file (atleast 12 names, columns are MonthName*Season)
# Q1>create a dataframe which contains only winter season months
# Q2>create a dataframe which contains only summer season months
# Q3>create a dataframe which contains only rainy season months
# Q4>create a dataframe which contains only winter and summer season months
# Q5>create a dataframe which not contains summer and rainy season months
# Q6>create a dataframe which contains either winter or rainy items

# %%
# 5. Create a month_names.xlsx file (atleast 12 names, columns are MonthName*Season)

# %%
M_names=pd.read_excel(r"C:\Users\hp\Downloads\Month_names.xlsx")
M_names
# Out:
#     S.No. Month Name  Season
# 0       1    January  Winter
# 1       2   February  Winter
# 2       3      March  Summer
# 3       4      April  Summer
# 4       5        May  Summer
# 5       6       June  Summer
# 6       7       July   Rainy
# 7       8     August   Rainy
# 8       9  September   Rainy
# 9      10    October   Rainy
# 10     11   November  Winter
# 11     12   December  Winter

# %%
# Q1>create a dataframe which contains only winter season months

# %%
# ----> Only 'Winter Season'

# %%
M_names[M_names["Season"]=="Winter"]
# Out:
#     S.No. Month Name  Season
# 0       1    January  Winter
# 1       2   February  Winter
# 10     11   November  Winter
# 11     12   December  Winter

# %%
# Q2>create a dataframe which contains only summer season months

# %%
# ----> Only 'Summer Season'

# %%
M_names[M_names["Season"]=="Summer"]
# Out:
#    S.No. Month Name  Season
# 2      3      March  Summer
# 3      4      April  Summer
# 4      5        May  Summer
# 5      6       June  Summer

# %%
# Q3>create a dataframe which contains only rainy season months

# %%
# ----> Only 'Rainy Season'

# %%
M_names[M_names["Season"]=="Rainy"]
# Out:
#    S.No. Month Name Season
# 6      7       July  Rainy
# 7      8     August  Rainy
# 8      9  September  Rainy
# 9     10    October  Rainy

# %%
# Q4>create a dataframe which contains only winter and summer season months

# %%
# ----> Only Winter and Summer Season

# %%
lst4=["Winter","Summer"]

M_names[M_names.Season.isin(lst4)]
# Out:
#     S.No. Month Name  Season
# 0       1    January  Winter
# 1       2   February  Winter
# 2       3      March  Summer
# 3       4      April  Summer
# 4       5        May  Summer
# 5       6       June  Summer
# 10     11   November  Winter
# 11     12   December  Winter

# %%
# Q5>create a dataframe which not contains summer and rainy season months

# %%
# ----> 'Not' Summer and Rainy Season (~)

# %%
lst5=["Summer","Rainy"]

M_names[~M_names.Season.isin(lst5)]
# Out:
#     S.No. Month Name  Season
# 0       1    January  Winter
# 1       2   February  Winter
# 10     11   November  Winter
# 11     12   December  Winter

# %%
# Q6>create a dataframe which contains either winter or rainy items

# %%
# ----> 'Either' Winter 'Or' Rainy Season

# %%
M_names[(M_names["Season"]=="Winter") | (M_names["Season"]=="Rainy")]
# Out:
#     S.No. Month Name  Season
# 0       1    January  Winter
# 1       2   February  Winter
# 6       7       July   Rainy
# 7       8     August   Rainy
# 8       9  September   Rainy
# 9      10    October   Rainy
# 10     11   November  Winter
# 11     12   December  Winter

# %%
# 6. Create a flower_names.xlsx file  (atleast 12 names, columns are FlowercolourName_in_English^FlowercolourName_in_Hindi^FlowercolourName_in_Telugu)
# Q1>create a dataframe which contains only red colour flower list
# Q2>create a dataframe which contains only white colour flower list
# Q3>create a dataframe which contains only pink colour flower list
# Q4>create a dataframe which contains only red and pink colour list
# Q5>create a dataframe which not contains red and white colour list
# Q6>create a dataframe which contains either red or pink colour list

# %%
# 6. Create a flower_names.xlsx file  (atleast 12 names, columns are FlowercolourName_in_English^FlowercolourName_in_Hindi^FlowercolourName_in_Telugu)

# %%
Flo_names=pd.read_excel(r"C:\Users\hp\Downloads\FColour.xlsx")
Flo_names
# Out:
#    F_Colour Eng.Name Hin.Name Tel.Name        Flowers
# 0       Red      Red     Laal   Earupu           Rose
# 1     White    White   Safhed   Telupu          Lilly
# 2       Red      Red     Laal   Earupu  Asiatic lilly
# 3      Pink     Pink   Gulabi     Roja           Rose
# 4     White    White   Safhed   Telupu           Rose
# 5      Pink     Pink   Gulabi     Roja   Spider lilly
# 6       Red      Red     Laal   Earupu       Hibiscus
# 7     White    White   Safhed   Telupu          Tulip
# 8      Pink     Pink   Gulabi     Roja          Daisy
# 9     White    White   Safhed   Telupu       Hibiscus
# 10      Red      Red     Laal   Earupu          Poppy
# 11     Pink     Pink   Gulabi     Roja          Lotus

# %%
# Q1>create a dataframe which contains only red colour flower list

# %%
# ----> Only 'Red Colour Flowers'

# %%
Flo_names[Flo_names["F_Colour"]=="Red"]
# Out:
#    F_Colour Eng.Name Hin.Name Tel.Name        Flowers
# 0       Red      Red     Laal   Earupu           Rose
# 2       Red      Red     Laal   Earupu  Asiatic lilly
# 6       Red      Red     Laal   Earupu       Hibiscus
# 10      Red      Red     Laal   Earupu          Poppy

# %%
# Q2>create a dataframe which contains only white colour flower list

# %%
# ----> Only 'White Colour Flowers'

# %%
Flo_names[Flo_names["F_Colour"]=="White"]
# Out:
#   F_Colour Eng.Name Hin.Name Tel.Name   Flowers
# 1    White    White   Safhed   Telupu     Lilly
# 4    White    White   Safhed   Telupu      Rose
# 7    White    White   Safhed   Telupu     Tulip
# 9    White    White   Safhed   Telupu  Hibiscus

# %%
# Q3>create a dataframe which contains only pink colour flower list

# %%
# ----> Only 'Pink Colour Flowers'

# %%
Flo_names[Flo_names["F_Colour"]=="Pink"]
# Out:
#    F_Colour Eng.Name Hin.Name Tel.Name       Flowers
# 3      Pink     Pink   Gulabi     Roja          Rose
# 5      Pink     Pink   Gulabi     Roja  Spider lilly
# 8      Pink     Pink   Gulabi     Roja         Daisy
# 11     Pink     Pink   Gulabi     Roja         Lotus

# %%
# Q4>create a dataframe which contains only red and pink colour list

# %%
lst6=["Red","Pink"]

Flo_names[Flo_names.F_Colour.isin(lst6)]
# Out:
#    F_Colour Eng.Name Hin.Name Tel.Name        Flowers
# 0       Red      Red     Laal   Earupu           Rose
# 2       Red      Red     Laal   Earupu  Asiatic lilly
# 3      Pink     Pink   Gulabi     Roja           Rose
# 5      Pink     Pink   Gulabi     Roja   Spider lilly
# 6       Red      Red     Laal   Earupu       Hibiscus
# 8      Pink     Pink   Gulabi     Roja          Daisy
# 10      Red      Red     Laal   Earupu          Poppy
# 11     Pink     Pink   Gulabi     Roja          Lotus

# %%
# Q5>create a dataframe which not contains red and white colour list

# %%
# ---->  'Not' Red and White Colour Flowers

# %%
lst7=["Red","White"]

Flo_names[~Flo_names.F_Colour.isin(lst7)]
# Out:
#    F_Colour Eng.Name Hin.Name Tel.Name       Flowers
# 3      Pink     Pink   Gulabi     Roja          Rose
# 5      Pink     Pink   Gulabi     Roja  Spider lilly
# 8      Pink     Pink   Gulabi     Roja         Daisy
# 11     Pink     Pink   Gulabi     Roja         Lotus

# %%
# Q6>create a dataframe which contains either red or pink colour list

# %%
# ----> 'Either' Red 'Or' Pink Colour Flowers

# %%
Flo_names[(Flo_names["F_Colour"]=="Red") | (Flo_names["F_Colour"]=="Pink")]
# Out:
#    F_Colour Eng.Name Hin.Name Tel.Name        Flowers
# 0       Red      Red     Laal   Earupu           Rose
# 2       Red      Red     Laal   Earupu  Asiatic lilly
# 3      Pink     Pink   Gulabi     Roja           Rose
# 5      Pink     Pink   Gulabi     Roja   Spider lilly
# 6       Red      Red     Laal   Earupu       Hibiscus
# 8      Pink     Pink   Gulabi     Roja          Daisy
# 10      Red      Red     Laal   Earupu          Poppy
# 11     Pink     Pink   Gulabi     Roja          Lotus
